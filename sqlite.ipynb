# %%
import sqlite3

conn = sqlite3.connect('/home/b_thampy/tiled/catalog.db')
cursor = conn.cursor()
cursor.execute("SELECT name from sqlite_master where type='table'")
tables = cursor.fetchall()
for table in tables:
    print(table[0])
# conn.close()
# Out:
# nodes
# metadata_fts5
# metadata_fts5_data
# metadata_fts5_idx
# metadata_fts5_docsize
# metadata_fts5_config
# structures
# assets
# data_sources
# revisions
# data_source_asset_association
# alembic_version

# %%
for
# Out:
# (1, 'sqlite://localhost//home/b_thampy/tiled/tabular.db', 0, None, None, None, '2025-07-18 22:07:54', '2025-07-18 22:07:54')

# %%
cursor.execute("SELECT * from data_sources")
sources = cursor.fetchall()
for source in sources:
    print(source)
# Out:
# (1, 4, 'a1b127285b5206446ff9d02128a8d716', 'application/x-tiled-sql-table', '{"table_name":"table_9bbcaad64c19cbf19595cbb24386d75c","dataset_id":1}', 'writable', 'table', '2025-07-18 22:07:54', '2025-07-18 22:07:54')
# (2, 8, 'a1b127285b5206446ff9d02128a8d716', 'application/x-tiled-sql-table', '{"table_name":"table_9bbcaad64c19cbf19595cbb24386d75c","dataset_id":2}', 'writable', 'table', '2025-07-18 22:13:46', '2025-07-18 22:13:46')
# (3, 12, '44e7329bfb769161bbc082126f06b5eb', 'application/x-tiled-sql-table', '{"table_name":"table_87d0e0581a83a2c936e5d5f9d5230f32","dataset_id":3}', 'writable', 'table', '2025-07-18 22:15:37', '2025-07-18 22:15:37')
# (4, 16, 'a1b127285b5206446ff9d02128a8d716', 'application/x-tiled-sql-table', '{"table_name":"table_9bbcaad64c19cbf19595cbb24386d75c","dataset_id":4}', 'writable', 'table', '2025-07-18 22:19:55', '2025-07-18 22:19:55')
# (5, 20, 'a1b127285b5206446ff9d02128a8d716', 'application/x-tiled-sql-table', '{"table_name":"table_9bbcaad64c19cbf19595cbb24386d75c","dataset_id":5}', 'writable', 'table', '2025-07-18 22:25:17', '2025-07-18 22:25:17')
# (6, 24, 'a1b127285b5206446ff9d02128a8d716', 'application/x-tiled-sql-table', '{"table_name":"table_9bbcaad64c19cbf19595cbb24386d75c","dataset_id":6}', 'writable', 'table', '2025-07-18 22:26:43', '2025-07-18 22:26:43')
# (7, 28, 'a1b127285b5206446ff9d02128a8d716', 'application/x-tiled-sql-table', '{"table_name":"table_9bbcaad64c19cbf19595cbb24386d75c","dataset_id":7}', 'writable', 'table', '2025-07-18 22:27:14', '2025-07-18 22:27:14')
# (8, 32, 'a1b127285b5206446ff9d02128a8d716', 'application/x-tiled-sql-table', '{"table_name":"table_9bbcaad64c19cbf19595cbb24386d75c","dataset_id":8}', 'writable', 'table', '2025-07-18 22:27:18', '2025-07-18 22:27:18')
# (9, 36, 'a1b127285b5206446ff9d02128a8d716', 'application/x-tiled-sql-table', '{"table_name":"table_9bbcaad64c19cbf19595cbb24386d75c","dataset_id":9}', 'writable', 'table', '2025-07-18 22:27:31', '2025-07-18 22:27:31')
# (10, 40, 'a1b127285b5206446ff9d02128a8d716', 'application/x-tiled-sql-table', '{"table_name":"table_9bbcaad64c19cbf19595cbb24386d75c","dataset_id":10}', 'writable', 'table', '2025-07-18 22:27:51', '2025-07-18 22:27:51')
# (11, 44, 'a1b127285b5206446ff9d02128a8d716', 'application/x-tiled-sql-table', '{"table_name":"table_9bbcaad64c19cbf19595cbb24386d75c","dataset_id":11}', 'writable', 'table', '2025-07-18 22:31:32', '2025-07-18 22:31:32')
# (12, 48, 'a1b127285b5206446ff9d02128a8d716', 'application/x-tiled-sql-table', '{"table_name":"table_9bbcaad64c19cbf19595cbb24386d75c","dataset_id":12}', 'writable', 'table', '2025-07-18 22:31:45', '2025-07-18 22:31:45')
# (13, 52, 'a1b127285b5206446ff9d02128a8d716', 'application/x-tiled-sql-table', '{"table_name":"table_9bbcaad64c19cbf19595cbb24386d75c","dataset_id":13}', 'writable', 'table', '2025-07-18 22:32:08', '2025-07-18 22:32:08')
# (14, 56, 'a1b127285b5206446ff9d02128a8d716', 'application/x-tiled-sql-table', '{"table_name":"table_9bbcaad64c19cbf19595cbb24386d75c","dataset_id":14}', 'writable', 'table', '2025-07-18 22:32:46', '2025-07-18 22:32:46')
# (15, 60, 'a1b127285b5206446ff9d02128a8d716', 'application/x-tiled-sql-table', '{"table_name":"table_9bbcaad64c19cbf19595cbb24386d75c","dataset_id":15}', 'writable', 'table', '2025-07-18 22:33:24', '2025-07-18 22:33:24')
# (16, 64, 'a1b127285b5206446ff9d02128a8d716', 'application/x-tiled-sql-table', '{"table_name":"table_9bbcaad64c19cbf19595cbb24386d75c","dataset_id":16}', 'writable', 'table', '2025-07-18 22:33:33', '2025-07-18 22:33:33')
# (17, 68, 'a1b127285b5206446ff9d02128a8d716', 'application/x-tiled-sql-table', '{"table_name":"table_9bbcaad64c19cbf19595cbb24386d75c","dataset_id":17}', 'writable', 'table', '2025-07-18 22:33:57', '2025-07-18 22:33:57')
# (18, 72, 'a1b127285b5206446ff9d02128a8d716', 'application/x-tiled-sql-table', '{"table_name":"table_9bbcaad64c19cbf19595cbb24386d75c","dataset_id":18}', 'writable', 'table', '2025-07-18 22:36:27', '2025-07-18 22:36:27')
# (19, 76, 'a1b127285b5206446ff9d02128a8d716', 'application/x-tiled-sql-table', '{"table_name":"table_9bbcaad64c19cbf19595cbb24386d75c","dataset_id":19}', 'writable', 'table', '2025-07-18 22:45:39', '2025-07-18 22:45:39')
# (20, 80, 'a1b127285b5206446ff9d02128a8d716', 'application/x-tiled-sql-table', '{"table_name":"table_9bbcaad64c19cbf19595cbb24386d75c","dataset_id":20}', 'writable', 'table', '2025-07-18 22:46:03', '2025-07-18 22:46:03')
# (21, 84, 'a1b127285b5206446ff9d02128a8d716', 'application/x-tiled-sql-table', '{"table_name":"table_9bbcaad64c19cbf19595cbb24386d75c","dataset_id":21}', 'writable', 'table', '2025-07-18 22:46:22', '2025-07-18 22:46:22')
# (22, 88, '44e7329bfb769161bbc082126f06b5eb', 'application/x-tiled-sql-table', '{"table_name":"table_87d0e0581a83a2c936e5d5f9d5230f32","dataset_id":22}', 'writable', 'table', '2025-07-18 22:47:31', '2025-07-18 22:47:31')
# (23, 92, '116effc3e33a582e5faa0ac4857b7083', 'application/x-tiled-sql-table', '{"table_name":"table_6623d9379746a04fca11c242f567fd73","dataset_id":23}', 'writable', 'table', '2025-07-18 22:48:13', '2025-07-18 22:48:13')

# %%
cursor.execute("SELECT * from assets")
assets = cursor.fetchall()
for asset in assets:
    print(asset)
# Out:
# (1, 'sqlite://localhost//home/b_thampy/tiled/tabular.db', 0, None, None, None, '2025-07-18 22:07:54', '2025-07-18 22:07:54')
